# %%
# Classes
class myClass:
    x=5

p1=myClass() #creating multiple objects from a class
p2=myClass()
p3=myClass()

print(p1.x)
print(p2.x)
print(p3.x)
# Out:
# 5
# 5
# 5

# %%
class Person:
    def __init__(self,name,age=25):
        self.name = name
        self.age = age

p1 = Person("Yulia")

print(p1.name, "is", p1.age)
# Out:
# Yulia is 25

# %%
# Class properties vs. Object properties

class Person:
    species = "Human" #class properties
    def __init__(self,name):
        self.name=name #instances properties

p1 = Person("Amanda")
p2 = Person("Branden")

Person.species = "Humaniod" #Modifying class property

p1.age = 25 #Adding new property

print(p1.species)
print(p2.species)
print(p1.name)
print(p1.age)
print(p2.name)
# Out:
# Humaniod
# Humaniod
# Amanda
# 25
# Branden

# %%
# Class inheritance
class Person:
    def __init__(self,fname,lname):
        self.fname = fname
        self.lname = lname

    def printname(self):
        print(self.fname, self.lname)
    
class Student(Person):
    def __init__(self,fname,lname):
        super().__init__(fname,lname)

p1=Student("Yulia","Lee")
p1.printname()
# Out:
# Yulia Lee

# %%
# Python polymorphism
# methods/functions/operators with the same name that can be executed on many objects or classes
class Car:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Drive!")

class Boat:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Sail!")

class Plane:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang")       #Create a Car object
boat1 = Boat("Ibiza", "Touring 20") #Create a Boat object
plane1 = Plane("Boeing", "747")     #Create a Plane object

for x in (car1, boat1, plane1):
  x.move()
# Out:
# Drive!
# Sail!
# Fly!

# %%
# Python Inner Classes

class Car:
    def __init__(self, make, model):
        self.make = make
        self.model = model
        self.engine = self.Engine()
    class Engine:
        def __init__(self):
            self.status = "Off"
        def start(self):
            self.status = "Running"
            print("Engine running")
        def stop(self):
            self.status = "Off"
            print("Engine stopped")
    def drive(self):
        if self.engine.status == "Running":
            print(f"Driving {self.make} {self.model}")
        else:
            print("Start your engine first!")


c1=Car("Toyota", "Corolla")  
c1.drive()
c1.engine.start()
c1.drive()
# Out:
# Start your engine first!
# Engine running
# Driving Toyota Corolla
