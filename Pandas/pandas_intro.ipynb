# %%
import pandas as pd

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

print(pd.DataFrame(mydataset))
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas

print(pandas.__version__)
# Out:
# 3.0.2

# %%
# Series - in pandas, it's like a column of a table. One-dimensional array holding data
import pandas as pd

a=[1,4,6]
myvar = pd.Series(a)
newvar = pd.Series(a,index=["x","y","z"]) #creating labels

print(myvar)
print(myvar[0]) #indexing

print(newvar)
print(newvar["y"]) #indexing with label
# Out:
# 0    1
# 1    4
# 2    6
# dtype: int64
# 1
# x    1
# y    4
# z    6
# dtype: int64
# 4

# %%
# Key/Value as Series
import pandas as pd

calories={"day1":180, "day2":300, "day3":400}
var=pd.Series(calories)
newvar=pd.Series(calories,index=["day1","day2"])

print(var)
print(newvar)
# Out:
# day1    180
# day2    300
# day3    400
# dtype: int64
# day1    180
# day2    300
# dtype: int64

# %%
# DataFrames - multi-dimensional tables
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
myvar = pd.DataFrame(data)

print(myvar)
print(myvar.loc[0]) #locating the first row
print(myvar.loc[[0,1]]) #locating the first and second row

newvar = pd.DataFrame(data,index=["day1","day2","day3"])
print(newvar)
print(newvar.loc["day2"])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# calories    420
# duration     50
# Name: 0, dtype: int64
#    calories  duration
# 0       420        50
# 1       380        40
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
# calories    380
# duration     40
# Name: day2, dtype: int64

# %%
# Load files into DataFrames
import pandas as pd

df=pd.read_csv('data.csv')

print(df)
# Out:
#   One Two Tree
# 0        1 2 3
